# %%
import pandas as pd
import numpy as np

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
dataframe=pd.DataFrame(exam_data,index=labels)
dataframe
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
#QUESTION 1 
dataframe.head(3)
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes

# %%
#QUESTION 2
dataframe.dropna()
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
#QUESTION 3 
data_name=dataframe.name
data_score=dataframe.score

print(dataframe[['name','score']])
# Out:
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# d      James    NaN
# e      Emily    9.0
# f    Michael   20.0
# g    Matthew   14.5
# h      Laura    NaN
# i      Kevin    8.0
# j      Jonas   19.0

# %%
#QUESTION 4 

dataframe.loc['k']={'name':"Suresh",'score':15.5, 'attempts': 1, 'qualify': "yes"}
dataframe
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# k     Suresh   15.5         1     yes

# %%
#QUESTION 5 
dataframe.drop(columns='attempts')
# Out:
#         name  score qualify
# 0  Anastasia   12.5     yes
# 1       Dima    9.0      no
# 2  Katherine   16.5     yes
# 3      James    NaN      no
# 4      Emily    9.0      no
# 5    Michael   20.0     yes
# 6    Matthew   14.5     yes
# 7      Laura    NaN      no
# 8      Kevin    8.0      no
# 9      Jonas   19.0     yes

# %%
#QUESTION 6 
dataframe['Success']=0

dataframe.loc[dataframe['score'] > 10, 'Success'] = 1 
dataframe
# Out:
#         name  score  attempts qualify  Success
# a  Anastasia   12.5         1     yes        1
# b       Dima    9.0         3      no        0
# c  Katherine   16.5         2     yes        1
# d      James    NaN         3      no        0
# e      Emily    9.0         2      no        0
# f    Michael   20.0         3     yes        1
# g    Matthew   14.5         1     yes        1
# h      Laura    NaN         1      no        0
# i      Kevin    8.0         2      no        0
# j      Jonas   19.0         1     yes        1
# k     Suresh   15.5         1     yes        1
